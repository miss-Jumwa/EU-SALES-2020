# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
EU=pd.read_csv(r"C:\Users\840 g3\Desktop\Data Science\T Salary Survey EU 2019.csv")

# %%
EU
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 0            Fullstack Developer                   13
# 1              Backend Developer                    3
# ...

# %%
EU.head()
# Out:
#            Zeitstempel   Age Gender    City Seniority level  \
# 0  02.12.2019 11:18:26  33.0   Male  Berlin          Senior
# 1  02.12.2019 11:18:35  29.0   Male  Berlin          Middle
# 2  02.12.2019 11:18:56   NaN   Male  Berlin          Middle
# 3  02.12.2019 11:19:08  30.0   Male  Berlin          Senior
# 4  02.12.2019 11:19:37  32.0   Male  Berlin          Senior
#
#   Position (without seniority)  Years of experience  \
# 0          Fullstack Developer                   13
# 1            Backend Developer                    3
# 2             Mobile Developer                    4
# 3            Backend Developer                    6
# 4           Embedded Developer                   10
#
#   Your main technology / programming language  \
# 0                                         PHP
# 1                                      Python
# 2                                      Kotlin
# 3                                         PHP
# 4                                       C/C++
#
# ...

# %%
EU.describe()
# Out:
#               Age  Years of experience  \
# count  882.000000           991.000000
# mean    32.416100             8.529768
# std      5.262496             5.036320
# min     20.000000             0.000000
# 25%     29.000000             5.000000
# 50%     32.000000             8.000000
# 75%     35.000000            11.000000
# max     54.000000            30.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                       990.000000    530.000000
# mean                                      72562.212121   7857.169811
# std                                       23947.379182  10320.628344
# min                                        6000.000000      0.000000
# 25%                                       60000.000000    300.000000
# 50%                                       70000.000000   5000.000000
# 75%                                       80000.000000  10000.000000
# ...

# %%
EU.isna()
# Out:
#      Zeitstempel    Age  Gender   City  Seniority level  \
# 0          False  False   False  False            False
# 1          False  False   False  False            False
# 2          False   True   False  False            False
# 3          False  False   False  False            False
# 4          False  False   False  False            False
# ..           ...    ...     ...    ...              ...
# 986        False  False   False  False            False
# 987        False  False   False  False            False
# 988        False  False   False  False            False
# 989        False  False   False  False            False
# 990        False  False   False  False            False
#
#      Position (without seniority)  Years of experience  \
# 0                           False                False
# 1                           False                False
# 2                           False                False
# 3                           False                False
# ...

# %%
EU.isna().sum()
# Out:
# Zeitstempel                                                                                               0
# Age                                                                                                     109
# Gender                                                                                                    0
# City                                                                                                      0
# Seniority level                                                                                          15
# Position (without seniority)                                                                              1
# Years of experience                                                                                       0
# Your main technology / programming language                                                              14
# Yearly brutto salary (without bonus and stocks)                                                           1
# ...

# %%
EU.hist(bins=60,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Years of experience'}>,
#         <AxesSubplot:title={'center':'Yearly brutto salary (without bonus and stocks)'}>],
#        [<AxesSubplot:title={'center':'Yearly bonus'}>,
#         <AxesSubplot:title={'center':'Yearly stocks'}>,
#         <AxesSubplot:title={'center':'Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country'}>],
#        [<AxesSubplot:title={'center':'Yearly bonus one year ago. Only answer if staying in same country'}>,
#         <AxesSubplot:title={'center':'Yearly stocks one year ago. Only answer if staying in same country'}>,
#         <AxesSubplot:title={'center':'Number of vacation days'}>],
#        [<AxesSubplot:title={'center':'Number of home office days per month'}>,
#         <AxesSubplot:title={'center':'0'}>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# histograms can be used to detect outliers

# %%
pd.DataFrame(EU['Age'].value_counts()).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
EU[['Age','Years of experience']].plot(kind='scatter',x='Age', y='Years of experience',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Years of experience'>

# %%
EU[['Age','Yearly bonus']].plot(kind='scatter',x='Age', y='Yearly bonus',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Yearly bonus'>

# %%
EU[['Age','Yearly stocks']].plot(kind='scatter',x='Age', y='Yearly stocks',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Yearly stocks'>

# %%
EU[['Age','Number of vacation days']].plot(kind='scatter',x='Age', y='Number of vacation days',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Number of vacation days'>
